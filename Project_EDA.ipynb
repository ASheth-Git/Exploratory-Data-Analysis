# %%
import numpy as np
import pandas as pd

# %%
x=pd.read_csv("protein.csv",sep=";")

# %%
x
# Out:
#     Molecule ChEMBL ID  Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0         CHEMBL221959    TOFACITINIB                   4            312.38
# 1        CHEMBL1614701    SELUMETINIB                   4            457.69
# 2        CHEMBL1822054            NaN                   0            460.88
# 3             CHEMBL10      SB-203580                   0            377.44
# 4        CHEMBL1836927            NaN                   0            767.90
# ..                 ...            ...                 ...               ...
# 744      CHEMBL3589752  IPP/CNRS-A017                   0            403.40
# 745      CHEMBL3799512         TP-004                   0            363.34
# 746      CHEMBL4563315            NaN                   0            325.85
# 747      CHEMBL1970104            NaN                   0            290.37
# 748         CHEMBL1421      DASATINIB                   4            488.02
#
#      #RO5 Violations  AlogP       Compound Key  \
# ...

# %%
x.shape
# Out:
# (749, 45)

# %%
x.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
columns_name=pd.DataFrame(x.columns,columns=["C_names"])

# %%
columns_name
# Out:
#                        C_names
# 0           Molecule ChEMBL ID
# 1                Molecule Name
# 2           Molecule Max Phase
# 3             Molecular Weight
# 4              #RO5 Violations
# 5                        AlogP
# 6                 Compound Key
# 7                       Smiles
# 8                Standard Type
# 9            Standard Relation
# 10              Standard Value
# 11              Standard Units
# 12               pChEMBL Value
# 13       Data Validity Comment
# 14                     Comment
# 15                    Uo Units
# 16       Ligand Efficiency BEI
# 17        Ligand Efficiency LE
# 18       Ligand Efficiency LLE
# 19       Ligand Efficiency SEI
# 20         Potential Duplicate
# 21             Assay ChEMBL ID
# 22           Assay Description
# 23                  Assay Type
# 24               BAO Format ID
# 25                   BAO Label
# 26              Assay Organism
# 27      Assay Tissue ChEMBL ID
# 28           Assay Tissue Name
# ...

# %%
columns_name.to_csv("protein_chembl_columns.csv",index=None)

# %%
ls
# Out:
# analyze_AVE_bias.py                    protein_chembl_columns.csv
# aspirin1.png                           protein.csv
# aspirin.mol                            protein_molecule_name_freq.csv
# aspirin.sdf                            remove_AVE_bias.py
# erk2.csv                               sample.csv
# imatinib.smi                           shared_data_mldd/
# Installation_for_Linux_Bash_macOS.pdf  Untitled.ipynb
# Installation_for_windows.pdf           v_a.csv
# L1.ipynb                               v_b.csv
# L2.ipynb                               v_c.csv
# name_of_protein                        v_d.csv
# Project_EDA.ipynb

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 749 entries, 0 to 748
# Data columns (total 45 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Molecule ChEMBL ID          749 non-null    object
#  1   Molecule Name               218 non-null    object
#  2   Molecule Max Phase          749 non-null    int64
#  3   Molecular Weight            749 non-null    float64
#  4   #RO5 Violations             749 non-null    int64
#  5   AlogP                       749 non-null    float64
#  6   Compound Key                749 non-null    object
#  7   Smiles                      749 non-null    object
#  8   Standard Type               749 non-null    object
#  9   Standard Relation           631 non-null    object
#  10  Standard Value              743 non-null    float64
#  11  Standard Units              749 non-null    object
#  12  pChEMBL Value               61 non-null     float64
# ...

# %%
x.describe(include=["object"])
# Out:
#        Molecule ChEMBL ID  Molecule Name Compound Key  \
# count                 749            218          749
# unique                713            195          712
# top          CHEMBL388978  STAUROSPORINE           24
# freq                    4              4            5
#
#                                                    Smiles Standard Type  \
# count                                                 749           749
# unique                                                713             9
# top     CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...            Ki
# freq                                                    4           461
#
#        Standard Relation Standard Units  Data Validity Comment   Comment  \
# count                631            749                      3       579
# unique                 4              2                      1         5
# top                  '>'             nM  Outside typical range  inactive
# ...

# %%
x['Molecule ChEMBL ID'].value_counts()
# Out:
# CHEMBL388978     4
# CHEMBL595143     3
# CHEMBL595373     3
# CHEMBL604483     3
# CHEMBL1970104    2
#                 ..
# CHEMBL1980163    1
# CHEMBL1993424    1
# CHEMBL1967560    1
# CHEMBL1969588    1
# CHEMBL4563315    1
# Name: Molecule ChEMBL ID, Length: 713, dtype: int64

# %%
counts=x['Molecule ChEMBL ID'].value_counts().reset_index()

# %%
counts.columns=["Molecule ChEMBL ID","counts"]

# %%
counts
# Out:
#     Molecule ChEMBL ID  counts
# 0         CHEMBL388978       4
# 1         CHEMBL595143       3
# 2         CHEMBL595373       3
# 3         CHEMBL604483       3
# 4        CHEMBL1970104       2
# ..                 ...     ...
# 708      CHEMBL1980163       1
# 709      CHEMBL1993424       1
# 710      CHEMBL1967560       1
# 711      CHEMBL1969588       1
# 712      CHEMBL4563315       1
#
# [713 rows x 2 columns]

# %%
counts=x['Molecular Weight'].value_counts().reset_index()
counts.columns=["Molecular Weight","counts"]
counts
# Out:
#      Molecular Weight  counts
# 0              359.39       5
# 1              466.54       4
# 2              371.44       3
# 3              398.48       3
# 4              399.43       3
# ..                ...     ...
# 615            291.14       1
# 616            334.81       1
# 617            522.65       1
# 618            379.45       1
# 619            325.85       1
#
# [620 rows x 2 columns]

# %%
counts=x['Molecule Name'].value_counts().reset_index()
counts.columns=["Molecule Name","counts"]
counts
# Out:
#      Molecule Name  counts
# 0    STAUROSPORINE       4
# 1        GEFITINIB       2
# 2     LESTAURTINIB       2
# 3        SORAFENIB       2
# 4         IMATINIB       2
# ..             ...     ...
# 190    MRL-SYKi-NC       1
# 191        BI 1230       1
# 192      TG100-115       1
# 193      SB-242235       1
# 194         TP-004       1
#
# [195 rows x 2 columns]

# %%
counts.to_csv("protein_molecule_name_freq.csv",index=None)

# %%
ls
# Out:
# analyze_AVE_bias.py                    protein_chembl_columns.csv
# aspirin1.png                           protein.csv
# aspirin.mol                            protein_molecule_name_freq.csv
# aspirin.sdf                            remove_AVE_bias.py
# erk2.csv                               sample.csv
# imatinib.smi                           shared_data_mldd/
# Installation_for_Linux_Bash_macOS.pdf  Untitled.ipynb
# Installation_for_windows.pdf           v_a.csv
# L1.ipynb                               v_b.csv
# L2.ipynb                               v_c.csv
# name_of_protein                        v_d.csv
# Project_EDA.ipynb

# %%
pd.set_option("display.precision",4)

# %%
x.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
subdata=x[['Molecule ChEMBL ID','Smiles', 'Standard Type', 'Standard Relation', 'Standard Value','Standard Units']]

# %%
subdata
# Out:
#     Molecule ChEMBL ID                                             Smiles  \
# 0         CHEMBL221959  C[C@@H]1CCN(C(=O)CC#N)C[C@@H]1N(C)c1ncnc2[nH]c...
# 1        CHEMBL1614701     Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21
# 2        CHEMBL1822054  CC(=O)Nc1cn2nc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(F)c...
# 3             CHEMBL10  C[S+]([O-])c1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccncc...
# 4        CHEMBL1836927  CC1(C)[C@@H](O)CC[C@@]2(C)[C@H]1CC[C@]1(C)[C@@...
# ..                 ...                                                ...
# 744      CHEMBL3589752   Cc1c(Oc2c(F)cccc2F)c(OC(C)C)nn1-c1ncc(C2CC2)cc1F
# 745      CHEMBL3799512  Cc1nc(N2CC[C@@H](O)C2)ncc1-c1cc(C(F)(F)F)cc2[n...
# 746      CHEMBL4563315              CC(C)Nc1sc(C(=O)c2ccc(Cl)s2)c(N)c1C#N
# 747      CHEMBL1970104        CC(C)(C)c1ccc2nc(-c3n[nH]c4ccccc34)[nH]c2c1
# 748         CHEMBL1421  Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(C...
#
#     Standard Type Standard Relation  Standard Value Standard Units
# ...

# %%
subdata.shape
# Out:
# (749, 6)

# %%
subdata['Standard Units'].value_counts()
# Out:
# nM    547
# %     202
# Name: Standard Units, dtype: int64

# %%
subdata_1=subdata['Standard Units'].str.contains("nM")

# %%
subdata_1
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 744    False
# 745    False
# 746    False
# 747     True
# 748     True
# Name: Standard Units, Length: 749, dtype: bool

# %%
subdata=subdata.dropna(axis=0)

# %%
subdata.shape
# Out:
# (631, 6)

# %%
subdata_1=subdata[subdata['Standard Units'].str.contains("nM")]

# %%
subdata_1
# Out:
#     Molecule ChEMBL ID                                             Smiles  \
# 0         CHEMBL221959  C[C@@H]1CCN(C(=O)CC#N)C[C@@H]1N(C)c1ncnc2[nH]c...
# 1        CHEMBL1614701     Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21
# 3             CHEMBL10  C[S+]([O-])c1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccncc...
# 8         CHEMBL608533  CO[C@@H]1[C@H](N(C)C(=O)c2ccccc2)C[C@H]2O[C@]1...
# 13       CHEMBL1974702                 Cc1nc2c(sc3c(Br)ccc(Cl)c32)c(=O)o1
# ..                 ...                                                ...
# 739      CHEMBL1986328      CN(C)C(=O)Nc1ccc2nc(-c3ccco3)c(-c3ccco3)nc2c1
# 740      CHEMBL1982361                 O=c1c(NCc2ccccc2F)c(Nc2ccncc2)c1=O
# 741      CHEMBL2000801  O=C(Nc1ccc(-c2cccc3sncc23)cc1)Nc1ccc(F)c(C(F)(...
# 747      CHEMBL1970104        CC(C)(C)c1ccc2nc(-c3n[nH]c4ccccc34)[nH]c2c1
# 748         CHEMBL1421  Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(C...
#
#     Standard Type Standard Relation  Standard Value Standard Units
# ...

# %%
subdata.sort_values('Standard Value', ascending = True)
# Out:
#     Molecule ChEMBL ID                                             Smiles  \
# 146      CHEMBL3628627  CS(=O)(=O)c1cccc(Nc2nccc(-c3sc(N4CCOCC4)nc3-c3...
# 306       CHEMBL166031        CC(C)(C)c1cc(NC(=O)Nc2ccc(Oc3ccncc3)cc2)no1
# 320      CHEMBL3746293  Cc1c(-c2cc(Nc3cc4n(n3)CCN(C)C4)c(=O)[nH]n2)ccc...
# 7         CHEMBL379300  Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4c[nH]c5ccc...
# 657      CHEMBL4528675  COc1ccc(N2C(=O)COc3ccc(-c4cnc(OC)c(NS(=O)(=O)c...
# ..                 ...                                                ...
# 550          CHEMBL941  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...
# 187       CHEMBL428690  CN1CC[C@H](c2c(O)cc(O)c3c(=O)cc(-c4ccccc4Cl)oc...
# 0         CHEMBL221959  C[C@@H]1CCN(C(=O)CC#N)C[C@@H]1N(C)c1ncnc2[nH]c...
# 375      CHEMBL4090364  CCN(CC)CCCC(C)Nc1nc(/C=C/c2c(Cl)cc(Cl)cc2Cl)nc...
# 633      CHEMBL4634634  C[C@@H]1C[C@H]1C(=O)N1CCN(c2cnc(C#N)c(-c3cnn(C...
#
#     Standard Type Standard Relation  Standard Value Standard Units
# ...

# %%
subdata.sort_values('Standard Value', ascending = True).reset_index()
# Out:
#      index Molecule ChEMBL ID  \
# 0      146      CHEMBL3628627
# 1      306       CHEMBL166031
# 2      320      CHEMBL3746293
# 3        7       CHEMBL379300
# 4      657      CHEMBL4528675
# ..     ...                ...
# 626    550          CHEMBL941
# 627    187       CHEMBL428690
# 628      0       CHEMBL221959
# 629    375      CHEMBL4090364
# 630    633      CHEMBL4634634
#
#                                                 Smiles Standard Type  \
# 0    CS(=O)(=O)c1cccc(Nc2nccc(-c3sc(N4CCOCC4)nc3-c3...    Inhibition
# 1          CC(C)(C)c1cc(NC(=O)Nc2ccc(Oc3ccncc3)cc2)no1    Inhibition
# 2    Cc1c(-c2cc(Nc3cc4n(n3)CCN(C)C4)c(=O)[nH]n2)ccc...    Inhibition
# 3    Cc1n[nH]c2ccc(-c3cncc(OC[C@@H](N)Cc4c[nH]c5ccc...    Inhibition
# 4    COc1ccc(N2C(=O)COc3ccc(-c4cnc(OC)c(NS(=O)(=O)c...    Inhibition
# ..                                                 ...           ...
# 626  Cc1ccc(NC(=O)c2ccc(CN3CCN(C)CC3)cc2)cc1Nc1nccc...            Kd
# ...

# %%
subdata['Standard Type'].value_counts()
# Out:
# Ki                   461
# Kd                    79
# Inhibition            48
# Activity              27
# Residual activity      9
# IC50                   7
# Name: Standard Type, dtype: int64

# %%
Ki=subdata[subdata['Standard Type'].str.contains('')]

# %%
Ki
# Out:
#     Molecule ChEMBL ID                                             Smiles  \
# 0         CHEMBL221959  C[C@@H]1CCN(C(=O)CC#N)C[C@@H]1N(C)c1ncnc2[nH]c...
# 1        CHEMBL1614701     Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21
# 2        CHEMBL1822054  CC(=O)Nc1cn2nc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(F)c...
# 3             CHEMBL10  C[S+]([O-])c1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccncc...
# 4        CHEMBL1836927  CC1(C)[C@@H](O)CC[C@@]2(C)[C@H]1CC[C@]1(C)[C@@...
# ..                 ...                                                ...
# 740      CHEMBL1982361                 O=c1c(NCc2ccccc2F)c(Nc2ccncc2)c1=O
# 741      CHEMBL2000801  O=C(Nc1ccc(-c2cccc3sncc23)cc1)Nc1ccc(F)c(C(F)(...
# 746      CHEMBL4563315              CC(C)Nc1sc(C(=O)c2ccc(Cl)s2)c(N)c1C#N
# 747      CHEMBL1970104        CC(C)(C)c1ccc2nc(-c3n[nH]c4ccccc34)[nH]c2c1
# 748         CHEMBL1421  Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(C...
#
#     Standard Type Standard Relation  Standard Value Standard Units
# ...

# %%
Ki['Standard Type'].value_counts()
# Out:
# Ki                   461
# Kd                    79
# Inhibition            48
# Activity              27
# Residual activity      9
# IC50                   7
# Name: Standard Type, dtype: int64

# %%
newdata=Ki[['Molecule ChEMBL ID','Smiles']]

# %%
newdata=Ki[['Molecule ChEMBL ID','Smiles','Standard Value']]

# %%
newdata
# Out:
#     Molecule ChEMBL ID                                             Smiles  \
# 0         CHEMBL221959  C[C@@H]1CCN(C(=O)CC#N)C[C@@H]1N(C)c1ncnc2[nH]c...
# 1        CHEMBL1614701     Cn1cnc2c(F)c(Nc3ccc(Br)cc3Cl)c(C(=O)NOCCO)cc21
# 2        CHEMBL1822054  CC(=O)Nc1cn2nc(-c3cnc(Cl)c(NS(=O)(=O)c4ccc(F)c...
# 3             CHEMBL10  C[S+]([O-])c1ccc(-c2nc(-c3ccc(F)cc3)c(-c3ccncc...
# 4        CHEMBL1836927  CC1(C)[C@@H](O)CC[C@@]2(C)[C@H]1CC[C@]1(C)[C@@...
# ..                 ...                                                ...
# 740      CHEMBL1982361                 O=c1c(NCc2ccccc2F)c(Nc2ccncc2)c1=O
# 741      CHEMBL2000801  O=C(Nc1ccc(-c2cccc3sncc23)cc1)Nc1ccc(F)c(C(F)(...
# 746      CHEMBL4563315              CC(C)Nc1sc(C(=O)c2ccc(Cl)s2)c(N)c1C#N
# 747      CHEMBL1970104        CC(C)(C)c1ccc2nc(-c3n[nH]c4ccccc34)[nH]c2c1
# 748         CHEMBL1421  Cc1nc(Nc2ncc(C(=O)Nc3c(C)cccc3Cl)s2)cc(N2CCN(C...
#
#      Standard Value
# 0          10000.00
# 1          10000.00
# ...

# %% [markdown]
# **Binary Classification**

# %%
newdata['Molecule ChEMBL ID'].value_counts()
# Out:
# CHEMBL388978     4
# CHEMBL595143     3
# CHEMBL595373     3
# CHEMBL604483     3
# CHEMBL509032     2
#                 ..
# CHEMBL1980163    1
# CHEMBL1993424    1
# CHEMBL1967560    1
# CHEMBL1969588    1
# CHEMBL4563315    1
# Name: Molecule ChEMBL ID, Length: 598, dtype: int64

# %%
newdata[newdata['Molecule ChEMBL ID'].str.contains('CHEMBL388978')]
# Out:
#     Molecule ChEMBL ID                                             Smiles  \
# 129       CHEMBL388978  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
# 376       CHEMBL388978  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
# 668       CHEMBL388978  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
# 679       CHEMBL388978  CN[C@@H]1C[C@H]2O[C@@](C)([C@@H]1OC)n1c3ccccc3...
#
#      Standard Value
# 129           392.0
# 376           260.0
# 668           492.0
# 679            65.0

# %%
ls
# Out:
# analyze_AVE_bias.py                    protein_chembl_columns.csv
# aspirin1.png                           protein.csv
# aspirin.mol                            protein_molecule_name_freq.csv
# aspirin.sdf                            remove_AVE_bias.py
# erk2.csv                               sample.csv
# imatinib.smi                           shared_data_mldd/
# Installation_for_Linux_Bash_macOS.pdf  Untitled.ipynb
# Installation_for_windows.pdf           v_a.csv
# L1.ipynb                               v_b.csv
# L2.ipynb                               v_c.csv
# name_of_protein                        v_d.csv
# Project_EDA.ipynb

# %%
y=pd.read_csv("erk2.csv",sep=";")

# %%
y.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
y["Molecule ChEMBL ID"].value_counts()
# Out:
# CHEMBL3590107    19
# CHEMBL388978     17
# CHEMBL3544964    16
# CHEMBL3590106    15
# CHEMBL4071576    14
#                  ..
# CHEMBL1436716     1
# CHEMBL1311642     1
# CHEMBL1509292     1
# CHEMBL1548000     1
# CHEMBL3658846     1
# Name: Molecule ChEMBL ID, Length: 20031, dtype: int64

# %%
new_data=y[["Molecule ChEMBL ID",'Standard Value']]

# %%
new_data
# Out:
#       Molecule ChEMBL ID  Standard Value
# 0          CHEMBL1351580       25118.900
# 1          CHEMBL1493884       39810.700
# 2          CHEMBL1386667       31622.800
# 3          CHEMBL1455249       15848.900
# 4          CHEMBL1451172        7943.300
# ...                  ...             ...
# 23225      CHEMBL4520788        4570.000
# 23226      CHEMBL2180604       30000.000
# 23227      CHEMBL4561806          89.000
# 23228      CHEMBL3658647           1.348
# 23229      CHEMBL3658846         376.200
#
# [23230 rows x 2 columns]

# %%
new_data.value_counts()
# Out:
# Molecule ChEMBL ID  Standard Value
# CHEMBL3590107       1.0               4
# CHEMBL3590106       0.3               3
# CHEMBL608533        10000.0           3
# CHEMBL124660        10000.0           3
# CHEMBL215803        1000.0            3
#                                      ..
# CHEMBL1471595       22387.2           1
# CHEMBL1471589       3162.3            1
# CHEMBL1471556       31622.8           1
# CHEMBL1471549       158.5             1
# CHEMBL998           19952.6           1
# Length: 21113, dtype: int64

# %%
new_data[new_data["Molecule ChEMBL ID"].str.contains('CHEMBL388978')]
# Out:
#       Molecule ChEMBL ID  Standard Value
# 339         CHEMBL388978           37.00
# 1689        CHEMBL388978         7300.00
# 3006        CHEMBL388978           82.00
# 3718        CHEMBL388978          100.30
# 6820        CHEMBL388978         4491.00
# 6827        CHEMBL388978          370.00
# 7769        CHEMBL388978          370.00
# 11784       CHEMBL388978         3948.00
# 12495       CHEMBL388978          100.31
# 12956       CHEMBL388978         1380.00
# 17518       CHEMBL388978         7300.00
# 17863       CHEMBL388978            2.50
# 19185       CHEMBL388978        34000.00
# 21227       CHEMBL388978           65.00
# 21341       CHEMBL388978            1.00
# 21376       CHEMBL388978          659.10
# 21951       CHEMBL388978         8451.00

# %%
new_data["New_Standard_Value"]=new_data[['Molecule ChEMBL ID','Standard Value']].groupby(["Molecule ChEMBL ID"])["Standard Value"].transform("mean")
# Out:
# /tmp/ipykernel_865466/1896529415.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["New_Standard_Value"]=new_data[['Molecule ChEMBL ID','Standard Value']].groupby(["Molecule ChEMBL ID"])["Standard Value"].transform("mean")

# %%
new_data.head()
# Out:
#   Molecule ChEMBL ID  Standard Value  New_Standard_Value
# 0      CHEMBL1351580         25118.9             25118.9
# 1      CHEMBL1493884         39810.7             39810.7
# 2      CHEMBL1386667         31622.8             31622.8
# 3      CHEMBL1455249         15848.9             15848.9
# 4      CHEMBL1451172          7943.3              7943.3

# %%
CHEMBL388978=new_data[new_data["Molecule ChEMBL ID"].str.contains('CHEMBL388978')]

# %%
CHEMBL388978
# Out:
#       Molecule ChEMBL ID  Standard Value  New_Standard_Value
# 339         CHEMBL388978           37.00           4038.6594
# 1689        CHEMBL388978         7300.00           4038.6594
# 3006        CHEMBL388978           82.00           4038.6594
# 3718        CHEMBL388978          100.30           4038.6594
# 6820        CHEMBL388978         4491.00           4038.6594
# 6827        CHEMBL388978          370.00           4038.6594
# 7769        CHEMBL388978          370.00           4038.6594
# 11784       CHEMBL388978         3948.00           4038.6594
# 12495       CHEMBL388978          100.31           4038.6594
# 12956       CHEMBL388978         1380.00           4038.6594
# 17518       CHEMBL388978         7300.00           4038.6594
# 17863       CHEMBL388978            2.50           4038.6594
# 19185       CHEMBL388978        34000.00           4038.6594
# 21227       CHEMBL388978           65.00           4038.6594
# ...

# %%
CHEMBL388978["Standard Value"].mean()
# Out:
# 4038.6594117647055

# %%
new_data=new_data.sort_values("New_Standard_Value",ascending=True)

# %%
new_data=new_data.dropna(axis=0)

# %%
new_data
# Out:
#       Molecule ChEMBL ID  Standard Value  New_Standard_Value
# 19851      CHEMBL2333128     -5.2000e+01         -5.2000e+01
# 5748       CHEMBL3815046     -3.2000e+01         -3.1000e+01
# 5771       CHEMBL3815046     -3.0000e+01         -3.1000e+01
# 11343       CHEMBL456252     -3.0280e+01         -2.8795e+01
# 6194        CHEMBL456252     -2.7310e+01         -2.8795e+01
# ...                  ...             ...                 ...
# 13584      CHEMBL2297163      1.0000e+06          1.0000e+06
# 14200      CHEMBL4125992      1.0000e+06          1.0000e+06
# 12442      CHEMBL2297161      1.0000e+06          1.0000e+06
# 894        CHEMBL2297162      1.0000e+06          1.0000e+06
# 10678      CHEMBL1350100      5.0119e+06          5.0119e+06
#
# [21365 rows x 3 columns]

# %%
new_data['Molecule ChEMBL ID'].value_counts()
# Out:
# CHEMBL3590107    19
# CHEMBL388978     17
# CHEMBL3544964    16
# CHEMBL3590106    15
# CHEMBL4071576    14
#                  ..
# CHEMBL1971141     1
# CHEMBL1375418     1
# CHEMBL1965131     1
# CHEMBL1984044     1
# CHEMBL1350100     1
# Name: Molecule ChEMBL ID, Length: 19194, dtype: int64

# %%
new_data=new_data.drop_duplicates('Molecule ChEMBL ID',keep="first")

# %%
new_data
# Out:
#       Molecule ChEMBL ID  Standard Value  New_Standard_Value
# 19851      CHEMBL2333128     -5.2000e+01         -5.2000e+01
# 5748       CHEMBL3815046     -3.2000e+01         -3.1000e+01
# 11343       CHEMBL456252     -3.0280e+01         -2.8795e+01
# 7391       CHEMBL3814140     -2.1000e+01         -2.6500e+01
# 12860       CHEMBL405665     -1.4000e+01         -1.8000e+01
# ...                  ...             ...                 ...
# 13584      CHEMBL2297163      1.0000e+06          1.0000e+06
# 14200      CHEMBL4125992      1.0000e+06          1.0000e+06
# 12442      CHEMBL2297161      1.0000e+06          1.0000e+06
# 894        CHEMBL2297162      1.0000e+06          1.0000e+06
# 10678      CHEMBL1350100      5.0119e+06          5.0119e+06
#
# [19194 rows x 3 columns]

# %%
new_data['Molecule ChEMBL ID'].value_counts()
# Out:
# CHEMBL2333128    1
# CHEMBL1548596    1
# CHEMBL1379900    1
# CHEMBL1966872    1
# CHEMBL1477044    1
#                 ..
# CHEMBL1325810    1
# CHEMBL1412005    1
# CHEMBL1566610    1
# CHEMBL1344662    1
# CHEMBL1350100    1
# Name: Molecule ChEMBL ID, Length: 19194, dtype: int64

# %%
new_data.head()
# Out:
#       Molecule ChEMBL ID  Standard Value  New_Standard_Value
# 19851      CHEMBL2333128          -52.00             -52.000
# 5748       CHEMBL3815046          -32.00             -31.000
# 11343       CHEMBL456252          -30.28             -28.795
# 7391       CHEMBL3814140          -21.00             -26.500
# 12860       CHEMBL405665          -14.00             -18.000

# %%
active=new_data.loc[new_data['New_Standard_Value']<=10000]

# %%
active
# Out:
#       Molecule ChEMBL ID  Standard Value  New_Standard_Value
# 19851      CHEMBL2333128          -52.00             -52.000
# 5748       CHEMBL3815046          -32.00             -31.000
# 11343       CHEMBL456252          -30.28             -28.795
# 7391       CHEMBL3814140          -21.00             -26.500
# 12860       CHEMBL405665          -14.00             -18.000
# ...                  ...             ...                 ...
# 20792      CHEMBL1416556        10000.00           10000.000
# 12022       CHEMBL473313        10000.00           10000.000
# 17222      CHEMBL1595576        10000.00           10000.000
# 21589      CHEMBL1495827        10000.00           10000.000
# 12032      CHEMBL1600898        10000.00           10000.000
#
# [8624 rows x 3 columns]

# %%
 inactive=new_data.loc[new_data['New_Standard_Value']>20000]

# %%
inactive
# Out:
#       Molecule ChEMBL ID  Standard Value  New_Standard_Value
# 11530        CHEMBL86754         39810.7          2.0052e+04
# 9926       CHEMBL1398137           354.8          2.0083e+04
# 12602       CHEMBL290106           385.0          2.0098e+04
# 16212      CHEMBL1730100          7943.3          2.0114e+04
# 4062       CHEMBL1474125           501.2          2.0156e+04
# ...                  ...             ...                 ...
# 13584      CHEMBL2297163       1000000.0          1.0000e+06
# 14200      CHEMBL4125992       1000000.0          1.0000e+06
# 12442      CHEMBL2297161       1000000.0          1.0000e+06
# 894        CHEMBL2297162       1000000.0          1.0000e+06
# 10678      CHEMBL1350100       5011872.3          5.0119e+06
#
# [7169 rows x 3 columns]

# %%
active['label']=1
# Out:
# /tmp/ipykernel_865466/1148142576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   active['label']=1

# %%
active.head()
# Out:
#       Molecule ChEMBL ID  Standard Value  New_Standard_Value  label
# 19851      CHEMBL2333128          -52.00             -52.000      1
# 5748       CHEMBL3815046          -32.00             -31.000      1
# 11343       CHEMBL456252          -30.28             -28.795      1
# 7391       CHEMBL3814140          -21.00             -26.500      1
# 12860       CHEMBL405665          -14.00             -18.000      1

# %%
inactive['label']=0
# Out:
# /tmp/ipykernel_865466/1824636394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   inactive['label']=0

# %%
inactive
# Out:
#       Molecule ChEMBL ID  Standard Value  New_Standard_Value  label
# 11530        CHEMBL86754         39810.7          2.0052e+04      0
# 9926       CHEMBL1398137           354.8          2.0083e+04      0
# 12602       CHEMBL290106           385.0          2.0098e+04      0
# 16212      CHEMBL1730100          7943.3          2.0114e+04      0
# 4062       CHEMBL1474125           501.2          2.0156e+04      0
# ...                  ...             ...                 ...    ...
# 13584      CHEMBL2297163       1000000.0          1.0000e+06      0
# 14200      CHEMBL4125992       1000000.0          1.0000e+06      0
# 12442      CHEMBL2297161       1000000.0          1.0000e+06      0
# 894        CHEMBL2297162       1000000.0          1.0000e+06      0
# 10678      CHEMBL1350100       5011872.3          5.0119e+06      0
#
# [7169 rows x 4 columns]

# %%
combined=pd.concat([active,inactive],axis=0)

# %%
combined
# Out:
#       Molecule ChEMBL ID  Standard Value  New_Standard_Value  label
# 19851      CHEMBL2333128     -5.2000e+01         -5.2000e+01      1
# 5748       CHEMBL3815046     -3.2000e+01         -3.1000e+01      1
# 11343       CHEMBL456252     -3.0280e+01         -2.8795e+01      1
# 7391       CHEMBL3814140     -2.1000e+01         -2.6500e+01      1
# 12860       CHEMBL405665     -1.4000e+01         -1.8000e+01      1
# ...                  ...             ...                 ...    ...
# 13584      CHEMBL2297163      1.0000e+06          1.0000e+06      0
# 14200      CHEMBL4125992      1.0000e+06          1.0000e+06      0
# 12442      CHEMBL2297161      1.0000e+06          1.0000e+06      0
# 894        CHEMBL2297162      1.0000e+06          1.0000e+06      0
# 10678      CHEMBL1350100      5.0119e+06          5.0119e+06      0
#
# [15793 rows x 4 columns]

# %%
labelled=combined[["Molecule ChEMBL ID","label"]]

# %%
labelled
# Out:
#       Molecule ChEMBL ID  label
# 19851      CHEMBL2333128      1
# 5748       CHEMBL3815046      1
# 11343       CHEMBL456252      1
# 7391       CHEMBL3814140      1
# 12860       CHEMBL405665      1
# ...                  ...    ...
# 13584      CHEMBL2297163      0
# 14200      CHEMBL4125992      0
# 12442      CHEMBL2297161      0
# 894        CHEMBL2297162      0
# 10678      CHEMBL1350100      0
#
# [15793 rows x 2 columns]

# %%
common = pd.merge(combined,y,on='Molecule ChEMBL ID')

# %%
common
# Out:
#       Molecule ChEMBL ID  Standard Value_x  New_Standard_Value  label  \
# 0          CHEMBL2333128       -5.2000e+01         -5.2000e+01      1
# 1          CHEMBL3815046       -3.2000e+01         -3.1000e+01      1
# 2          CHEMBL3815046       -3.2000e+01         -3.1000e+01      1
# 3           CHEMBL456252       -3.0280e+01         -2.8795e+01      1
# 4           CHEMBL456252       -3.0280e+01         -2.8795e+01      1
# ...                  ...               ...                 ...    ...
# 17877      CHEMBL4125992        1.0000e+06          1.0000e+06      0
# 17878      CHEMBL4125992        1.0000e+06          1.0000e+06      0
# 17879      CHEMBL2297161        1.0000e+06          1.0000e+06      0
# 17880      CHEMBL2297162        1.0000e+06          1.0000e+06      0
# 17881      CHEMBL1350100        5.0119e+06          5.0119e+06      0
#
#       Molecule Name  Molecule Max Phase Molecular Weight #RO5 Violations  \
# ...

# %%
common['Molecule ChEMBL ID'].value_counts()
# Out:
# CHEMBL3590107    19
# CHEMBL388978     17
# CHEMBL3544964    16
# CHEMBL3590106    15
# CHEMBL4071576    14
#                  ..
# CHEMBL1391643     1
# CHEMBL1530382     1
# CHEMBL1458928     1
# CHEMBL1507243     1
# CHEMBL1350100     1
# Name: Molecule ChEMBL ID, Length: 15793, dtype: int64

# %%
common=common[['Molecule ChEMBL ID','label','Smiles']]

# %%
common
# Out:
#       Molecule ChEMBL ID  label  \
# 0          CHEMBL2333128      1
# 1          CHEMBL3815046      1
# 2          CHEMBL3815046      1
# 3           CHEMBL456252      1
# 4           CHEMBL456252      1
# ...                  ...    ...
# 17877      CHEMBL4125992      0
# 17878      CHEMBL4125992      0
# 17879      CHEMBL2297161      0
# 17880      CHEMBL2297162      0
# 17881      CHEMBL1350100      0
#
#                                                   Smiles
# 0      C[C@@H](Nc1c(C(N)=O)nnc2cc(-c3ccc(S(C)(=O)=O)c...
# 1      CCCCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23...
# 2      CCCCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23...
# 3      COc1cc2c(cc1Nc1nc(Nc3ccsc3C(N)=O)c3cc[nH]c3n1)...
# 4      COc1cc2c(cc1Nc1nc(Nc3ccsc3C(N)=O)c3cc[nH]c3n1)...
# ...                                                  ...
# 17877                       NCc1cn(Cc2ccccc2C(F)(F)F)cn1
# 17878                       NCc1cn(Cc2ccccc2C(F)(F)F)cn1
# ...

# %%
common=common.drop_duplicates('Molecule ChEMBL ID',keep='first')

# %%
common
# Out:
#       Molecule ChEMBL ID  label  \
# 0          CHEMBL2333128      1
# 1          CHEMBL3815046      1
# 3           CHEMBL456252      1
# 5          CHEMBL3814140      1
# 7           CHEMBL405665      1
# ...                  ...    ...
# 17876      CHEMBL2297163      0
# 17877      CHEMBL4125992      0
# 17879      CHEMBL2297161      0
# 17880      CHEMBL2297162      0
# 17881      CHEMBL1350100      0
#
#                                                   Smiles
# 0      C[C@@H](Nc1c(C(N)=O)nnc2cc(-c3ccc(S(C)(=O)=O)c...
# 1      CCCCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23...
# 3      COc1cc2c(cc1Nc1nc(Nc3ccsc3C(N)=O)c3cc[nH]c3n1)...
# 5      CCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23)n...
# 7                           Nc1nccc(-c2c[nH]c3ncccc23)n1
# ...                                                  ...
# 17876    Cc1cccn2cc(CN(Cc3nc4ccccc4c(=O)[nH]3)C(C)C)nc12
# 17877                       NCc1cn(Cc2ccccc2C(F)(F)F)cn1
# ...

# %%
common
# Out:
#       Molecule ChEMBL ID  label  \
# 0          CHEMBL2333128      1
# 1          CHEMBL3815046      1
# 3           CHEMBL456252      1
# 5          CHEMBL3814140      1
# 7           CHEMBL405665      1
# ...                  ...    ...
# 17876      CHEMBL2297163      0
# 17877      CHEMBL4125992      0
# 17879      CHEMBL2297161      0
# 17880      CHEMBL2297162      0
# 17881      CHEMBL1350100      0
#
#                                                   Smiles
# 0      C[C@@H](Nc1c(C(N)=O)nnc2cc(-c3ccc(S(C)(=O)=O)c...
# 1      CCCCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23...
# 3      COc1cc2c(cc1Nc1nc(Nc3ccsc3C(N)=O)c3cc[nH]c3n1)...
# 5      CCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23)n...
# 7                           Nc1nccc(-c2c[nH]c3ncccc23)n1
# ...                                                  ...
# 17876    Cc1cccn2cc(CN(Cc3nc4ccccc4c(=O)[nH]3)C(C)C)nc12
# 17877                       NCc1cn(Cc2ccccc2C(F)(F)F)cn1
# ...

# %%
common["Smiles"].value_counts()
# Out:
# C[C@@H](Nc1c(C(N)=O)nnc2cc(-c3ccc(S(C)(=O)=O)cc3)ccc12)C1CC1                                                                                                        1
# CN1C/C(=C\c2ccccn2)C(=O)/C(=C/c2ccccn2)C1                                                                                                                           1
# CCC(=O)O[C@H]1C(O[C@@H]2C(C)[C@H](O[C@H]3C[C@@](C)(OC)C(O)C(C)O3)C(C)C(=O)OC(CC)[C@@](C)(O)C(O)[C@H](C)C(=O)C(C)C[C@]2(C)O)OC(C)CC1N(C)C.CCCCCCCCCCCCOS(=O)(=O)O    1
# Cl.Cl.N=C(NCCCCCCNC(=N)NC(=N)Nc1ccc(Cl)cc1)NC(=N)Nc1ccc(Cl)cc1                                                                                                      1
# C#Cc1ncc(OC[C@@H](N)Cc2c[nH]c3ccccc23)cc1-c1ccc2cnccc2c1                                                                                                            1
# ...

# %%
common=common.drop_duplicates('Smiles',keep='first')

# %%
common
# Out:
#       Molecule ChEMBL ID  label  \
# 0          CHEMBL2333128      1
# 1          CHEMBL3815046      1
# 3           CHEMBL456252      1
# 5          CHEMBL3814140      1
# 7           CHEMBL405665      1
# ...                  ...    ...
# 17876      CHEMBL2297163      0
# 17877      CHEMBL4125992      0
# 17879      CHEMBL2297161      0
# 17880      CHEMBL2297162      0
# 17881      CHEMBL1350100      0
#
#                                                   Smiles
# 0      C[C@@H](Nc1c(C(N)=O)nnc2cc(-c3ccc(S(C)(=O)=O)c...
# 1      CCCCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23...
# 3      COc1cc2c(cc1Nc1nc(Nc3ccsc3C(N)=O)c3cc[nH]c3n1)...
# 5      CCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23)n...
# 7                           Nc1nccc(-c2c[nH]c3ncccc23)n1
# ...                                                  ...
# 17876    Cc1cccn2cc(CN(Cc3nc4ccccc4c(=O)[nH]3)C(C)C)nc12
# 17877                       NCc1cn(Cc2ccccc2C(F)(F)F)cn1
# ...

# %%
common.to_csv("EDA.csv",index=None)

# %%
ls
# Out:
# analyze_AVE_bias.py                    Project_EDA.ipynb
# aspirin1.png                           protein_chembl_columns.csv
# aspirin.mol                            protein.csv
# aspirin.sdf                            protein_molecule_name_freq.csv
# EDA.csv                                remove_AVE_bias.py
# erk2.csv                               sample.csv
# imatinib.smi                           shared_data_mldd/
# Installation_for_Linux_Bash_macOS.pdf  Untitled.ipynb
# Installation_for_windows.pdf           v_a.csv
# L1.ipynb                               v_b.csv
# L2.ipynb                               v_c.csv
# name_of_protein                        v_d.csv

# %%
common['New_id']=common['Molecule ChEMBL ID'].astype(str)+"_"+common['label'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Molecule ChEMBL ID'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
common
# Out:
#       Molecule ChEMBL ID  label  \
# 0          CHEMBL2333128      1
# 1          CHEMBL3815046      1
# 3           CHEMBL456252      1
# 5          CHEMBL3814140      1
# 7           CHEMBL405665      1
# ...                  ...    ...
# 17876      CHEMBL2297163      0
# 17877      CHEMBL4125992      0
# 17879      CHEMBL2297161      0
# 17880      CHEMBL2297162      0
# 17881      CHEMBL1350100      0
#
#                                                   Smiles       New_column  \
# 0      C[C@@H](Nc1c(C(N)=O)nnc2cc(-c3ccc(S(C)(=O)=O)c...  CHEMBL2333128_1
# 1      CCCCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23...  CHEMBL3815046_1
# 3      COc1cc2c(cc1Nc1nc(Nc3ccsc3C(N)=O)c3cc[nH]c3n1)...   CHEMBL456252_1
# 5      CCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23)n...  CHEMBL3814140_1
# 7                           Nc1nccc(-c2c[nH]c3ncccc23)n1   CHEMBL405665_1
# ...                                                  ...              ...
# ...

# %%
common= common[['Smiles','New_id']]

# %%
common
# Out:
#                                                   Smiles           New_id
# 0      C[C@@H](Nc1c(C(N)=O)nnc2cc(-c3ccc(S(C)(=O)=O)c...  CHEMBL2333128_1
# 1      CCCCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23...  CHEMBL3815046_1
# 3      COc1cc2c(cc1Nc1nc(Nc3ccsc3C(N)=O)c3cc[nH]c3n1)...   CHEMBL456252_1
# 5      CCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23)n...  CHEMBL3814140_1
# 7                           Nc1nccc(-c2c[nH]c3ncccc23)n1   CHEMBL405665_1
# ...                                                  ...              ...
# 17876    Cc1cccn2cc(CN(Cc3nc4ccccc4c(=O)[nH]3)C(C)C)nc12  CHEMBL2297163_0
# 17877                       NCc1cn(Cc2ccccc2C(F)(F)F)cn1  CHEMBL4125992_0
# 17879  Cc1nc[nH]c1[C@@H]1c2nc[nH]c2CCN1Cc1nc2ccccc2[nH]1  CHEMBL2297161_0
# 17880   Cc1nc[nH]c1[C@H]1c2nc[nH]c2CCN1Cc1nc2ccccc2[nH]1  CHEMBL2297162_0
# 17881        CCC(=O)Nc1cc(C(=O)NCC2CCCN2CC)c(OC)cc1N(C)C  CHEMBL1350100_0
#
# [15765 rows x 2 columns]

# %%
 common.to_csv("erk2_labelled_smile.smi",index=None,header=False,sep="\t")

# %%
ls
# Out:
# analyze_AVE_bias.py                    name_of_protein
# aspirin1.png                           Project_EDA.ipynb
# aspirin.mol                            protein_chembl_columns.csv
# aspirin.sdf                            protein.csv
# EDA.csv                                protein_molecule_name_freq.csv
# erk2.csv                               remove_AVE_bias.py
# erk2_labelled_smile.csv                sample.csv
# erk2_labelled_smile.smi                shared_data_mldd/
# imatinib.smi                           Untitled.ipynb
# Installation_for_Linux_Bash_macOS.pdf  v_a.csv
# Installation_for_windows.pdf           v_b.csv
# L1.ipynb                               v_c.csv
# L2.ipynb                               v_d.csv

# %%
y
# Out:
#       Molecule ChEMBL ID Molecule Name  Molecule Max Phase Molecular Weight  \
# 0          CHEMBL1351580           NaN                   0           316.36
# 1          CHEMBL1493884           NaN                   0           210.30
# 2          CHEMBL1386667           NaN                   0           460.56
# 3          CHEMBL1455249           NaN                   0           230.31
# 4          CHEMBL1451172           NaN                   0           499.04
# ...                  ...           ...                 ...              ...
# 23225      CHEMBL4520788           NaN                   0           448.59
# 23226      CHEMBL2180604       TAK-593                   1           445.48
# 23227      CHEMBL4561806           NaN                   0           242.30
# 23228      CHEMBL3658647           NaN                   0           477.55
# 23229      CHEMBL3658846           NaN                   0           338.37
#
#       #RO5 Violations AlogP Compound Key  \
# ...

# %%
y.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties'],
# ...

# %%
y.isnull().sum()
# Out:
# Molecule ChEMBL ID                0
# Molecule Name                 19644
# Molecule Max Phase                0
# Molecular Weight                  0
# #RO5 Violations                   0
# AlogP                             0
# Compound Key                      0
# Smiles                          112
# Standard Type                     0
# Standard Relation              1865
# Standard Value                 1865
# Standard Units                 1870
# pChEMBL Value                  5553
# Data Validity Comment         23179
# Comment                        3738
# Uo Units                       1890
# Ligand Efficiency BEI         19643
# Ligand Efficiency LE          19643
# Ligand Efficiency LLE         19643
# Ligand Efficiency SEI         19643
# Potential Duplicate               0
# Assay ChEMBL ID                   0
# Assay Description                 0
# Assay Type                        0
# BAO Format ID                     0
# BAO Label                         0
# ...

# %%
common
# Out:
#                                                   Smiles           New_id
# 0      C[C@@H](Nc1c(C(N)=O)nnc2cc(-c3ccc(S(C)(=O)=O)c...  CHEMBL2333128_1
# 1      CCCCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23...  CHEMBL3815046_1
# 3      COc1cc2c(cc1Nc1nc(Nc3ccsc3C(N)=O)c3cc[nH]c3n1)...   CHEMBL456252_1
# 5      CCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23)n...  CHEMBL3814140_1
# 7                           Nc1nccc(-c2c[nH]c3ncccc23)n1   CHEMBL405665_1
# ...                                                  ...              ...
# 17876    Cc1cccn2cc(CN(Cc3nc4ccccc4c(=O)[nH]3)C(C)C)nc12  CHEMBL2297163_0
# 17877                       NCc1cn(Cc2ccccc2C(F)(F)F)cn1  CHEMBL4125992_0
# 17879  Cc1nc[nH]c1[C@@H]1c2nc[nH]c2CCN1Cc1nc2ccccc2[nH]1  CHEMBL2297161_0
# 17880   Cc1nc[nH]c1[C@H]1c2nc[nH]c2CCN1Cc1nc2ccccc2[nH]1  CHEMBL2297162_0
# 17881        CCC(=O)Nc1cc(C(=O)NCC2CCCN2CC)c(OC)cc1N(C)C  CHEMBL1350100_0
#
# [15765 rows x 2 columns]

# %%
common
# Out:
#                                                   Smiles           New_id
# 0      C[C@@H](Nc1c(C(N)=O)nnc2cc(-c3ccc(S(C)(=O)=O)c...  CHEMBL2333128_1
# 1      CCCCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23...  CHEMBL3815046_1
# 3      COc1cc2c(cc1Nc1nc(Nc3ccsc3C(N)=O)c3cc[nH]c3n1)...   CHEMBL456252_1
# 5      CCc1cc(-c2c[nH]c3ncc(-c4cnn(C5CCNCC5)c4)cc23)n...  CHEMBL3814140_1
# 7                           Nc1nccc(-c2c[nH]c3ncccc23)n1   CHEMBL405665_1
# ...                                                  ...              ...
# 17876    Cc1cccn2cc(CN(Cc3nc4ccccc4c(=O)[nH]3)C(C)C)nc12  CHEMBL2297163_0
# 17877                       NCc1cn(Cc2ccccc2C(F)(F)F)cn1  CHEMBL4125992_0
# 17879  Cc1nc[nH]c1[C@@H]1c2nc[nH]c2CCN1Cc1nc2ccccc2[nH]1  CHEMBL2297161_0
# 17880   Cc1nc[nH]c1[C@H]1c2nc[nH]c2CCN1Cc1nc2ccccc2[nH]1  CHEMBL2297162_0
# 17881        CCC(=O)Nc1cc(C(=O)NCC2CCCN2CC)c(OC)cc1N(C)C  CHEMBL1350100_0
#
# [15765 rows x 2 columns]

# %%
labelled
# Out:
#       Molecule ChEMBL ID  label
# 19851      CHEMBL2333128      1
# 5748       CHEMBL3815046      1
# 11343       CHEMBL456252      1
# 7391       CHEMBL3814140      1
# 12860       CHEMBL405665      1
# ...                  ...    ...
# 13584      CHEMBL2297163      0
# 14200      CHEMBL4125992      0
# 12442      CHEMBL2297161      0
# 894        CHEMBL2297162      0
# 10678      CHEMBL1350100      0
#
# [15793 rows x 2 columns]

# %%
freq_binder=y.groupby('Molecule ChEMBL ID').filter(lambda x: len(x)>10)

# %%
freq_binder['Molecule ChEMBL ID'].value_counts()
# Out:
# CHEMBL3590107    19
# CHEMBL388978     17
# CHEMBL3544964    16
# CHEMBL3590106    15
# CHEMBL4071576    14
# CHEMBL10         12
# CHEMBL4482864    11
# CHEMBL4538174    11
# Name: Molecule ChEMBL ID, dtype: int64

# %%
freq_binder
# Out:
#       Molecule ChEMBL ID  Molecule Name  Molecule Max Phase Molecular Weight  \
# 40         CHEMBL3544964   RAVOXERTINIB                   1           440.87
# 50         CHEMBL4071576            NaN                   0           442.53
# 339         CHEMBL388978  STAUROSPORINE                   0           466.54
# 655        CHEMBL3590107            NaN                   0           587.69
# 1642            CHEMBL10      SB-203580                   0           377.44
# ...                  ...            ...                 ...              ...
# 23033      CHEMBL4538174            NaN                   0           311.35
# 23040      CHEMBL4538174            NaN                   0           311.35
# 23069      CHEMBL4538174            NaN                   0           311.35
# 23080      CHEMBL3590107            NaN                   0           587.69
# 23224      CHEMBL4538174            NaN                   0           311.35
#
# ...

# %%
c=y.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
c=y.corr()

# %%
sns.heatmap(c,cmap="BrBG",annot=True)
# Out:
# <AxesSubplot:>
