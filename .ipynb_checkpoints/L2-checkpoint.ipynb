# %%
import pandas as pd
import numpy as np

# %%
x=pd.read_csv("sample.csv")

# %%
x.head(10)
# Out:
#        ChEMBL ID             Type  Molecular Weight Molecular Formula  \
# 0  CHEMBL4450911              NaN            303.19       C15H18BNO3S
# 1  CHEMBL4444926              NaN            303.19       C15H18BNO3S
# 2  CHEMBL4439726              NaN            307.18       C14H18BNO4S
# 3  CHEMBL4460127              NaN            307.18       C14H18BNO4S
# 4   CHEMBL253224   Small molecule            311.40        C15H21NO4S
# 5   CHEMBL405232   Small molecule            313.33        C15H24NO4P
# 6   CHEMBL258333   Small molecule            315.39        C17H17NO3S
# 7   CHEMBL257727   Small molecule            329.42        C18H19NO3S
# 8  CHEMBL4451026  Medium molecule            343.26       C18H22BNO3S
# 9   CHEMBL257726   Small molecule            343.45        C19H21NO3S
#
#                                               Smiles
# 0         C[C@H](CS)C(=O)N[C@H](B(O)O)c1ccc2ccccc2c1
# 1        C[C@H](CS)C(=O)N[C@@H](B(O)O)c1ccc2ccccc2c1
# ...

# %%
x.tail()
# Out:
#        ChEMBL ID            Type  Molecular Weight Molecular Formula  \
# 38  CHEMBL350414  Small molecule            405.52        C24H23NO3S
# 39  CHEMBL163454  Small molecule            405.52        C24H23NO3S
# 40  CHEMBL409721  Small molecule            410.41       C19H27N2O6P
# 41  CHEMBL271224  Small molecule            411.57        C24H29NO3S
# 42  CHEMBL271224  Large molecule            411.57        C24H29NO3S
#
#                                                Smiles
# 38  O=C(N[C@@H](Cc1ccc(-c2ccccc2)cc1)C(=O)O)[C@@H]...
# 39  O=C(O)[C@H](Cc1ccc(-c2ccccc2)cc1)NC(=O)[C@H](S...
# 40  CC(=O)N[C@@H](C)C(=O)N1CCC[C@@H]1P(=O)(O)C[C@@...
# 41  O=C(N[C@@H](Cc1ccc(-c2ccccc2)cc1)C(=O)O)[C@@H]...
# 42  O=C(N[C@@H](Cc1ccc(-c2ccccc2)cc1)C(=O)O)[C@@H]...

# %%
x.shape
# Out:
# (43, 5)

# %%
x.shape[0]
# Out:
# 43

# %%
x.shape[1]
# Out:
# 5

# %%
x.columns
# Out:
# Index(['ChEMBL ID', 'Type', 'Molecular Weight', 'Molecular Formula', 'Smiles'], dtype='object')

# %%
x.describe()
# Out:
#        Molecular Weight
# count         43.000000
# mean         367.714419
# std           34.073065
# min          303.190000
# 25%          344.455000
# 50%          371.500000
# 75%          397.475000
# max          411.570000

# %%
x1=x['ChEMBL ID']

# %%
x1
# Out:
# 0     CHEMBL4450911
# 1     CHEMBL4444926
# 2     CHEMBL4439726
# 3     CHEMBL4460127
# 4      CHEMBL253224
# 5      CHEMBL405232
# 6      CHEMBL258333
# 7      CHEMBL257727
# 8     CHEMBL4451026
# 9      CHEMBL257726
# 10     CHEMBL404044
# 11     CHEMBL253428
# 12     CHEMBL400527
# 13     CHEMBL412123
# 14     CHEMBL409713
# 15     CHEMBL269997
# 16     CHEMBL257229
# 17     CHEMBL269996
# 18     CHEMBL271225
# 19     CHEMBL401397
# 20     CHEMBL257270
# 21     CHEMBL398545
# 22     CHEMBL252391
# 23     CHEMBL252417
# 24     CHEMBL404117
# 25     CHEMBL271223
# 26     CHEMBL252003
# 27     CHEMBL254282
# 28     CHEMBL251804
# 29     CHEMBL437595
# 30    CHEMBL4202767
# 31     CHEMBL411298
# 32     CHEMBL257026
# 33    CHEMBL3235416
# 34     CHEMBL254493
# 35     CHEMBL254495
# 36     CHEMBL254703
# 37     CHEMBL258683
# 38     CHEMBL350414
# 39     CHEMBL163454
# 40     CHEMBL409721
# 41     CHEMBL271224
# 42     CHEMBL271224
# Name: ChEMBL ID, dtype: object

# %%
x2=x['Molecular Weight']

# %%
x['Molecular Weight'].sum()
# Out:
# 15811.72

# %%
x['Molecular Weight'].min()
# Out:
# 303.19

# %%
x['Molecular Weight'].max()
# Out:
# 411.57

# %%
x['Molecular Weight'].mean()
# Out:
# 367.71441860465114

# %%
x['Molecular Weight'].median()
# Out:
# 371.5

# %%
x['Molecular Weight'].idxmin()
# Out:
# 0

# %%
x['Molecular Weight'].idxmax()
# Out:
# 41

# %%
v_data={"v_name":["v1","v2","v3"]}

# %%
v_data
# Out:
# {'v_name': ['v1', 'v2', 'v3']}

# %%
vaccines=pd.DataFrame(v_data)

# %%
vaccines
# Out:
#   v_name
# 0     v1
# 1     v2
# 2     v3

# %%
v_data={"v_name":["v1","v2","v3"],"activity":["A","I","A"]}

# %%
v_data
# Out:
# {'v_name': ['v1', 'v2', 'v3'], 'activity': ['A', 'I', 'A']}

# %%
vaccines=pd.DataFrame(v_data)

# %%
vaccines
# Out:
#   v_name activity
# 0     v1        A
# 1     v2        I
# 2     v3        A

# %%
vaccines.to_csv("v_a.csv")

# %%
vaccines.to_csv("v_b.csv",sep="\t")

# %%
vaccines.to_csv("v_c.csv",sep="\t",index=None)

# %%
vaccines.to_csv("v_d.csv",sep="\t",index=None,header=None)

# %% [markdown]
# ##### **Series**

# %%
data=[1,2,3,4]

# %%
index=["a","b","c","d"]

# %%
p_series=pd.Series(data,index)

# %%
p_series
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
data={"a":1,"b":2,"c":3,"d":4}

# %%
p_series_1=pd.Series(data)

# %%
p_series_1
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
p_series_2=pd.Series("I",index=["s1","s2","s3"])

# %%
p_series_2
# Out:
# s1    I
# s2    I
# s3    I
# dtype: object

# %%
p_series_2=pd.Series(5.0,index=["s1","s2","s3"])

# %%
p_series_2
# Out:
# s1    5.0
# s2    5.0
# s3    5.0
# dtype: float64

# %%
p_series_1
p_series_1[p_series_1>2]
# Out:
# c    3
# d    4
# dtype: int64

# %%
p_series_1.shape
# Out:
# (4,)

# %%
p_series_1[p_series_1>2]=9

# %%
p_series_1
# Out:
# a    1
# b    2
# c    9
# d    9
# dtype: int64

# %%
p_series_1["a"]=15

# %%
p_series_1[0:3]
# Out:
# a    15
# b     2
# c     9
# dtype: int64

# %% [markdown]
# Practice

# %%
c1=["c1","c2","c3","c4"]
c2=[100,400,600,8000]
c=pd.Series(c2,c1)
c.median()
# Out:
# 500.0

# %%
c={"c1":100,"c2":400,"c3":600,"c4":8000}
c_ans=pd.Series(c)
c_ans.median()
# Out:
# 500.0

# %%
c_data={"Index":["c1","c2","c3","c4"],"Activity":[100,400,600,8000]}
c_ans_1=pd.Series(c_data)
c_ans_1
# Out:
# Index            [c1, c2, c3, c4]
# Activity    [100, 400, 600, 8000]
# dtype: object

# %%
c_data={"Index":["c1","c2","c3","c4"],"Activity":[100,400,600,8000]}
c_ans_1=pd.DataFrame(c_data)
c_ans_1.shape
# Out:
# (4, 2)

# %%
c_data={"Index":["c1","c2","c3","c4"],"Activity":[100,400,600,8000]}
c_ans_1=pd.DataFrame(c_data,index=None)
c_ans_1['Activity'].median()
# Out:
# 500.0

# %%
data=np.random.randint(0,50,size=8)
x=pd.Series(data)
x.median()
# Out:
# 29.0

# %% [markdown]
# **DATA FRAME**

# %%
x=pd.read_csv("sample.csv")

# %%
x.head()
# Out:
#        ChEMBL ID            Type  Molecular Weight Molecular Formula  \
# 0  CHEMBL4450911             NaN            303.19       C15H18BNO3S
# 1  CHEMBL4444926             NaN            303.19       C15H18BNO3S
# 2  CHEMBL4439726             NaN            307.18       C14H18BNO4S
# 3  CHEMBL4460127             NaN            307.18       C14H18BNO4S
# 4   CHEMBL253224  Small molecule            311.40        C15H21NO4S
#
#                                               Smiles
# 0         C[C@H](CS)C(=O)N[C@H](B(O)O)c1ccc2ccccc2c1
# 1        C[C@H](CS)C(=O)N[C@@H](B(O)O)c1ccc2ccccc2c1
# 2        C[C@H](CS)C(=O)N[C@@H](Cc1coc2ccccc12)B(O)O
# 3         C[C@H](CS)C(=O)N[C@H](Cc1coc2ccccc12)B(O)O
# 4  CC[C@@H](C)[C@H](S)C(=O)N[C@@H](Cc1ccc(O)cc1)C...

# %%
x.tail()
# Out:
#        ChEMBL ID            Type  Molecular Weight Molecular Formula  \
# 38  CHEMBL350414  Small molecule            405.52        C24H23NO3S
# 39  CHEMBL163454  Small molecule            405.52        C24H23NO3S
# 40  CHEMBL409721  Small molecule            410.41       C19H27N2O6P
# 41  CHEMBL271224  Small molecule            411.57        C24H29NO3S
# 42  CHEMBL271224  Large molecule            411.57        C24H29NO3S
#
#                                                Smiles
# 38  O=C(N[C@@H](Cc1ccc(-c2ccccc2)cc1)C(=O)O)[C@@H]...
# 39  O=C(O)[C@H](Cc1ccc(-c2ccccc2)cc1)NC(=O)[C@H](S...
# 40  CC(=O)N[C@@H](C)C(=O)N1CCC[C@@H]1P(=O)(O)C[C@@...
# 41  O=C(N[C@@H](Cc1ccc(-c2ccccc2)cc1)C(=O)O)[C@@H]...
# 42  O=C(N[C@@H](Cc1ccc(-c2ccccc2)cc1)C(=O)O)[C@@H]...

# %%
x.iloc[0:10]
# Out:
#        ChEMBL ID             Type  Molecular Weight Molecular Formula  \
# 0  CHEMBL4450911              NaN            303.19       C15H18BNO3S
# 1  CHEMBL4444926              NaN            303.19       C15H18BNO3S
# 2  CHEMBL4439726              NaN            307.18       C14H18BNO4S
# 3  CHEMBL4460127              NaN            307.18       C14H18BNO4S
# 4   CHEMBL253224   Small molecule            311.40        C15H21NO4S
# 5   CHEMBL405232   Small molecule            313.33        C15H24NO4P
# 6   CHEMBL258333   Small molecule            315.39        C17H17NO3S
# 7   CHEMBL257727   Small molecule            329.42        C18H19NO3S
# 8  CHEMBL4451026  Medium molecule            343.26       C18H22BNO3S
# 9   CHEMBL257726   Small molecule            343.45        C19H21NO3S
#
#                                               Smiles
# 0         C[C@H](CS)C(=O)N[C@H](B(O)O)c1ccc2ccccc2c1
# 1        C[C@H](CS)C(=O)N[C@@H](B(O)O)c1ccc2ccccc2c1
# ...

# %%
x["Type"]=x["Type"].fillna("Hellothere")

# %%
x
# Out:
#         ChEMBL ID             Type  Molecular Weight Molecular Formula  \
# 0   CHEMBL4450911            Hello            303.19       C15H18BNO3S
# 1   CHEMBL4444926            Hello            303.19       C15H18BNO3S
# 2   CHEMBL4439726            Hello            307.18       C14H18BNO4S
# 3   CHEMBL4460127            Hello            307.18       C14H18BNO4S
# 4    CHEMBL253224   Small molecule            311.40        C15H21NO4S
# 5    CHEMBL405232   Small molecule            313.33        C15H24NO4P
# 6    CHEMBL258333   Small molecule            315.39        C17H17NO3S
# 7    CHEMBL257727   Small molecule            329.42        C18H19NO3S
# 8   CHEMBL4451026  Medium molecule            343.26       C18H22BNO3S
# 9    CHEMBL257726   Small molecule            343.45        C19H21NO3S
# 10   CHEMBL404044   Small molecule            343.45        C19H21NO3S
# 11   CHEMBL253428   Small molecule            345.46        C19H23NO3S
# ...

# %%
x.columns[4]
# Out:
# 'Smiles'

# %%
x1=x[x.columns[0:2]]
x1
# Out:
#         ChEMBL ID             Type
# 0   CHEMBL4450911            Hello
# 1   CHEMBL4444926            Hello
# 2   CHEMBL4439726            Hello
# 3   CHEMBL4460127            Hello
# 4    CHEMBL253224   Small molecule
# 5    CHEMBL405232   Small molecule
# 6    CHEMBL258333   Small molecule
# 7    CHEMBL257727   Small molecule
# 8   CHEMBL4451026  Medium molecule
# 9    CHEMBL257726   Small molecule
# 10   CHEMBL404044   Small molecule
# 11   CHEMBL253428   Small molecule
# 12   CHEMBL400527   Small molecule
# 13   CHEMBL412123   Small molecule
# 14   CHEMBL409713   Small molecule
# 15   CHEMBL269997   Small molecule
# 16   CHEMBL257229   Small molecule
# 17   CHEMBL269996   Small molecule
# 18   CHEMBL271225   Small molecule
# 19   CHEMBL401397   Small molecule
# 20   CHEMBL257270   Small molecule
# 21   CHEMBL398545   Small molecule
# 22   CHEMBL252391   Small molecule
# 23   CHEMBL252417   Small molecule
# 24   CHEMBL404117   Small molecule
# 25   CHEMBL271223   Small molecule
# ...

# %%
x['ChEMBL ID'].head(10)
# Out:
# 0    CHEMBL4450911
# 1    CHEMBL4444926
# 2    CHEMBL4439726
# 3    CHEMBL4460127
# 4     CHEMBL253224
# 5     CHEMBL405232
# 6     CHEMBL258333
# 7     CHEMBL257727
# 8    CHEMBL4451026
# 9     CHEMBL257726
# Name: ChEMBL ID, dtype: object

# %%
x[:3]['ChEMBL ID']
# Out:
# 0    CHEMBL4450911
# 1    CHEMBL4444926
# 2    CHEMBL4439726
# Name: ChEMBL ID, dtype: object

# %%
x2=x[0:4][['ChEMBL ID','Type']]
x2
# Out:
#        ChEMBL ID   Type
# 0  CHEMBL4450911  Hello
# 1  CHEMBL4444926  Hello
# 2  CHEMBL4439726  Hello
# 3  CHEMBL4460127  Hello

# %%
x['New_column']=x['Molecular Weight']+x['Molecular Weight'].median()*100

# %%
x[['Molecular Weight','New_column']]
# Out:
#     Molecular Weight  New_column
# 0             303.19    37453.19
# 1             303.19    37453.19
# 2             307.18    37457.18
# 3             307.18    37457.18
# 4             311.40    37461.40
# 5             313.33    37463.33
# 6             315.39    37465.39
# 7             329.42    37479.42
# 8             343.26    37493.26
# 9             343.45    37493.45
# 10            343.45    37493.45
# 11            345.46    37495.46
# 12            345.46    37495.46
# 13            347.35    37497.35
# 14            355.33    37505.33
# 15            357.48    37507.48
# 16            369.49    37519.49
# 17            371.50    37521.50
# 18            371.50    37521.50
# 19            371.50    37521.50
# 20            371.50    37521.50
# 21            371.50    37521.50
# 22            371.50    37521.50
# 23            375.84    37525.84
# 24            383.51    37533.51
# 25            385.53    37535.53
# 26            387.50    37537.50
# ...

# %%
x.iloc[0:10,2:4]
# Out:
#    Molecular Weight Molecular Formula
# 0            303.19       C15H18BNO3S
# 1            303.19       C15H18BNO3S
# 2            307.18       C14H18BNO4S
# 3            307.18       C14H18BNO4S
# 4            311.40        C15H21NO4S
# 5            313.33        C15H24NO4P
# 6            315.39        C17H17NO3S
# 7            329.42        C18H19NO3S
# 8            343.26       C18H22BNO3S
# 9            343.45        C19H21NO3S

# %%
x1=x.iloc[0:10]
x2=x.iloc[20:30]
x3=pd.concat([x1,x2],axis=0)
x3
# Out:
#         ChEMBL ID             Type  Molecular Weight Molecular Formula  \
# 0   CHEMBL4450911            Hello            303.19       C15H18BNO3S
# 1   CHEMBL4444926            Hello            303.19       C15H18BNO3S
# 2   CHEMBL4439726            Hello            307.18       C14H18BNO4S
# 3   CHEMBL4460127            Hello            307.18       C14H18BNO4S
# 4    CHEMBL253224   Small molecule            311.40        C15H21NO4S
# 5    CHEMBL405232   Small molecule            313.33        C15H24NO4P
# 6    CHEMBL258333   Small molecule            315.39        C17H17NO3S
# 7    CHEMBL257727   Small molecule            329.42        C18H19NO3S
# 8   CHEMBL4451026  Medium molecule            343.26       C18H22BNO3S
# 9    CHEMBL257726   Small molecule            343.45        C19H21NO3S
# 20   CHEMBL257270   Small molecule            371.50        C21H25NO3S
# 21   CHEMBL398545   Small molecule            371.50        C21H25NO3S
# ...

# %%
x1=x.iloc[0:10]
x2=x.iloc[20:30]
x3=pd.concat([x1,x2],axis=0)
x3
# Out:
#         ChEMBL ID             Type  Molecular Weight Molecular Formula  \
# 0   CHEMBL4450911            Hello            303.19       C15H18BNO3S
# 1   CHEMBL4444926            Hello            303.19       C15H18BNO3S
# 2   CHEMBL4439726            Hello            307.18       C14H18BNO4S
# 3   CHEMBL4460127            Hello            307.18       C14H18BNO4S
# 4    CHEMBL253224   Small molecule            311.40        C15H21NO4S
# 5    CHEMBL405232   Small molecule            313.33        C15H24NO4P
# 6    CHEMBL258333   Small molecule            315.39        C17H17NO3S
# 7    CHEMBL257727   Small molecule            329.42        C18H19NO3S
# 8   CHEMBL4451026  Medium molecule            343.26       C18H22BNO3S
# 9    CHEMBL257726   Small molecule            343.45        C19H21NO3S
# 20   CHEMBL257270   Small molecule            371.50        C21H25NO3S
# 21   CHEMBL398545   Small molecule            371.50        C21H25NO3S
# ...

# %%
x["New_comumn_dummy"]=0

# %%
x.head()
# Out:
#        ChEMBL ID            Type  Molecular Weight Molecular Formula  \
# 0  CHEMBL4450911           Hello            303.19       C15H18BNO3S
# 1  CHEMBL4444926           Hello            303.19       C15H18BNO3S
# 2  CHEMBL4439726           Hello            307.18       C14H18BNO4S
# 3  CHEMBL4460127           Hello            307.18       C14H18BNO4S
# 4   CHEMBL253224  Small molecule            311.40        C15H21NO4S
#
#                                               Smiles  New_comumn_dummy
# 0         C[C@H](CS)C(=O)N[C@H](B(O)O)c1ccc2ccccc2c1                 0
# 1        C[C@H](CS)C(=O)N[C@@H](B(O)O)c1ccc2ccccc2c1                 0
# 2        C[C@H](CS)C(=O)N[C@@H](Cc1coc2ccccc12)B(O)O                 0
# 3         C[C@H](CS)C(=O)N[C@H](Cc1coc2ccccc12)B(O)O                 0
# 4  CC[C@@H](C)[C@H](S)C(=O)N[C@@H](Cc1ccc(O)cc1)C...                 0

# %%
x4=x.loc[x['Molecular Weight']>=400]
x4.tail()
x4["label"]="Interested"
# Out:
# /tmp/ipykernel_691636/2928797681.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x4["label"]="Interested"

# %%
x4=x4.sort_values("Molecular Weight", ascending=False)
x4
# Out:
#         ChEMBL ID            Type  Molecular Weight Molecular Formula  \
# 41   CHEMBL271224  Small molecule            411.57        C24H29NO3S
# 42   CHEMBL271224  Large molecule            411.57        C24H29NO3S
# 40   CHEMBL409721  Small molecule            410.41       C19H27N2O6P
# 38   CHEMBL350414  Small molecule            405.52        C24H23NO3S
# 39   CHEMBL163454  Small molecule            405.52        C24H23NO3S
# 37   CHEMBL258683  Small molecule            405.39        C20H24NO6P
# 34   CHEMBL254493  Small molecule            401.53        C22H27NO4S
# 35   CHEMBL254495  Small molecule            401.53        C22H27NO4S
# 36   CHEMBL254703  Small molecule            401.53        C22H27NO4S
# 33  CHEMBL3235416  Small molecule            401.47        C20H27N5O4
#
#                                                Smiles  New_comumn_dummy  \
# 41  O=C(N[C@@H](Cc1ccc(-c2ccccc2)cc1)C(=O)O)[C@@H]...                 0
# ...

# %%
x5=x["ChEMBL ID"].value_counts().reset_index()

# %%
x5.columns=["Name","counts"]

# %%
x5.to_csv("sample.csv",index=None,header=None)

# %%
x.assign(new_column=x['Molecular Weight']/10)
# Out:
#         ChEMBL ID             Type  Molecular Weight Molecular Formula  \
# 0   CHEMBL4450911              NaN            303.19       C15H18BNO3S
# 1   CHEMBL4444926              NaN            303.19       C15H18BNO3S
# 2   CHEMBL4439726              NaN            307.18       C14H18BNO4S
# 3   CHEMBL4460127              NaN            307.18       C14H18BNO4S
# 4    CHEMBL253224   Small molecule            311.40        C15H21NO4S
# 5    CHEMBL405232   Small molecule            313.33        C15H24NO4P
# 6    CHEMBL258333   Small molecule            315.39        C17H17NO3S
# 7    CHEMBL257727   Small molecule            329.42        C18H19NO3S
# 8   CHEMBL4451026  Medium molecule            343.26       C18H22BNO3S
# 9    CHEMBL257726   Small molecule            343.45        C19H21NO3S
# 10   CHEMBL404044   Small molecule            343.45        C19H21NO3S
# 11   CHEMBL253428   Small molecule            345.46        C19H23NO3S
# ...

# %%
x["ChEMBL ID"][0:x.shape[0]-20]
# Out:
# 0     CHEMBL4450911
# 1     CHEMBL4444926
# 2     CHEMBL4439726
# 3     CHEMBL4460127
# 4      CHEMBL253224
# 5      CHEMBL405232
# 6      CHEMBL258333
# 7      CHEMBL257727
# 8     CHEMBL4451026
# 9      CHEMBL257726
# 10     CHEMBL404044
# 11     CHEMBL253428
# 12     CHEMBL400527
# 13     CHEMBL412123
# 14     CHEMBL409713
# 15     CHEMBL269997
# 16     CHEMBL257229
# 17     CHEMBL269996
# 18     CHEMBL271225
# 19     CHEMBL401397
# 20     CHEMBL257270
# 21     CHEMBL398545
# 22     CHEMBL252391
# Name: ChEMBL ID, dtype: object

# %%
x.iloc[0:15,0:2].head()
# Out:
#        ChEMBL ID            Type
# 0  CHEMBL4450911             NaN
# 1  CHEMBL4444926             NaN
# 2  CHEMBL4439726             NaN
# 3  CHEMBL4460127             NaN
# 4   CHEMBL253224  Small molecule

# %%
x.loc[(x['Molecular Weight']>=400) & (x['Molecular Weight']<=410)]
# Out:
#         ChEMBL ID            Type  Molecular Weight Molecular Formula  \
# 33  CHEMBL3235416  Small molecule            401.47        C20H27N5O4
# 34   CHEMBL254493  Small molecule            401.53        C22H27NO4S
# 35   CHEMBL254495  Small molecule            401.53        C22H27NO4S
# 36   CHEMBL254703  Small molecule            401.53        C22H27NO4S
# 37   CHEMBL258683  Small molecule            405.39        C20H24NO6P
# 38   CHEMBL350414  Small molecule            405.52        C24H23NO3S
# 39   CHEMBL163454  Small molecule            405.52        C24H23NO3S
#
#                                                Smiles
# 33  CNC(=O)[C@H](Cc1c[nH]cn1)NC(=O)CN(CCCc1ccccc1)...
# 34  CC[C@@H](C)[C@H](S)C(=O)N[C@@H](Cc1ccccc1OCc1c...
# 35  CC[C@@H](C)[C@H](S)C(=O)N[C@@H](Cc1cccc(OCc2cc...
# 36  CC[C@@H](C)[C@H](S)C(=O)N[C@@H](Cc1ccc(OCc2ccc...
# 37  C[C@@H](NC(=O)OCc1ccccc1)P(=O)(O)C[C@@H](Cc1cc...
# 38  O=C(N[C@@H](Cc1ccc(-c2ccccc2)cc1)C(=O)O)[C@@H]...
# ...

# %%
x.head()
# Out:
#        ChEMBL ID            Type  Molecular Weight Molecular Formula  \
# 0  CHEMBL4450911             NaN            303.19       C15H18BNO3S
# 1  CHEMBL4444926             NaN            303.19       C15H18BNO3S
# 2  CHEMBL4439726             NaN            307.18       C14H18BNO4S
# 3  CHEMBL4460127             NaN            307.18       C14H18BNO4S
# 4   CHEMBL253224  Small molecule            311.40        C15H21NO4S
#
#                                               Smiles
# 0         C[C@H](CS)C(=O)N[C@H](B(O)O)c1ccc2ccccc2c1
# 1        C[C@H](CS)C(=O)N[C@@H](B(O)O)c1ccc2ccccc2c1
# 2        C[C@H](CS)C(=O)N[C@@H](Cc1coc2ccccc12)B(O)O
# 3         C[C@H](CS)C(=O)N[C@H](Cc1coc2ccccc12)B(O)O
# 4  CC[C@@H](C)[C@H](S)C(=O)N[C@@H](Cc1ccc(O)cc1)C...

# %%
x[x['Molecular Weight'].between(400,410)]
# Out:
#         ChEMBL ID            Type  Molecular Weight Molecular Formula  \
# 33  CHEMBL3235416  Small molecule            401.47        C20H27N5O4
# 34   CHEMBL254493  Small molecule            401.53        C22H27NO4S
# 35   CHEMBL254495  Small molecule            401.53        C22H27NO4S
# 36   CHEMBL254703  Small molecule            401.53        C22H27NO4S
# 37   CHEMBL258683  Small molecule            405.39        C20H24NO6P
# 38   CHEMBL350414  Small molecule            405.52        C24H23NO3S
# 39   CHEMBL163454  Small molecule            405.52        C24H23NO3S
#
#                                                Smiles
# 33  CNC(=O)[C@H](Cc1c[nH]cn1)NC(=O)CN(CCCc1ccccc1)...
# 34  CC[C@@H](C)[C@H](S)C(=O)N[C@@H](Cc1ccccc1OCc1c...
# 35  CC[C@@H](C)[C@H](S)C(=O)N[C@@H](Cc1cccc(OCc2cc...
# 36  CC[C@@H](C)[C@H](S)C(=O)N[C@@H](Cc1ccc(OCc2ccc...
# 37  C[C@@H](NC(=O)OCc1ccccc1)P(=O)(O)C[C@@H](Cc1cc...
# 38  O=C(N[C@@H](Cc1ccc(-c2ccccc2)cc1)C(=O)O)[C@@H]...
# ...

# %%
x1=x.loc[x['Molecular Formula']=='C20H27N5O4']
