# %%
from rdkit import rdBase
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
# Out:
# [20:33:20] Enabling RDKit 2019.09.3 jupyter extensions
# RDKit WARNING: [20:33:20] Enabling RDKit 2019.09.3 jupyter extensions

# %%
x = Chem.MolFromSmiles("CC(=O)OC1=CC=CC=C1C(=O)O")

# %%
x

# %%
Draw.MolToFile(x , "aspirin1.png")

# %%
from platform import python_version
python_version()
# Out:
# '3.8.13'

# %%
ls
# Out:
# analyze_AVE_bias.py  erk2.csv                               remove_AVE_bias.py
# aspirin1.png         imatinib.smi                           sample.csv
# aspirin.mol          Installation_for_Linux_Bash_macOS.pdf  shared_data_mldd/
# aspirin.sdf          Installation_for_windows.pdf           Untitled.ipynb

# %%
x=Chem.SmilesMolSupplier("imatinib.smi",delimiter="\t",titleLine=True)

# %%
x
